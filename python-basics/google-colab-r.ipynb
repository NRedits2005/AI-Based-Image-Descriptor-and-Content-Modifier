# %%
install.packages("DBI")
install.packages("odbc")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
library(DBI)
library(odbc)

# %%
install.packages("DBI")
install.packages("RPostgres")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
library(DBI)
library(RPostgres)

# %%
con <- dbConnect(
  RPostgres::Postgres(),
  host = "localhost",
  port = 5432,
  dbname = "placement_prep",
  user = "postgres",
  password = "2005"
)
# Out:
# Error: connection to server at "localhost" (::1), port 5432 failed: Connection refused
# 	Is the server running on that host and accepting TCP/IP connections?
# connection to server at "localhost" (127.0.0.1), port 5432 failed: Connection refused
# 	Is the server running on that host and accepting TCP/IP connections?
#
# Traceback:
#
# 1. dbConnect(RPostgres::Postgres(), host = "localhost", port = 5432,
#  .     dbname = "placement_prep", user = "postgresql", password = "2005")
# 2. .local(drv, ...)
# 3. connection_create(names(opts), as.vector(opts), check_interrupts)
# 4. .handleSimpleError(function (cnd)
#  . {
#  .     watcher$capture_plot_and_output()
#  .     cnd <- sanitize_call(cnd)
#  .     watcher$push(cnd)
#  .     switch(on_error, continue = invokeRestart("eval_continue"),
#  .         stop = invokeRestart("eval_stop"), error = NULL)
# ...
